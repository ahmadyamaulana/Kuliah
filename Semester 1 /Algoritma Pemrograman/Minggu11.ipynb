# %%
import matematika

print("Luas lingkaran = ", matematika.l_lingkaran())
print("Luas persegi = ", matematika.l_persegi())
print("Luas persegi panjang = ", matematika.l_persegi_panjang())
# Out:
# Masukkan jari-jari lingkaran: 7
# Luas lingkaran =  153.86
# Masukkan sisi persegi: 15
# Luas persegi =  225.0
# Masukkan panjang persegi panjang: 23
# Masukkan lebar persegi panjang: 23
# Luas persegi panjang =  529.0

# %%
#isi modul yang di buat
phi = 3.14

def l_lingkaran():
  jari = float(input("Masukkan jari-jari lingkaran: "))
  return phi * jari * jari

def l_persegi():
  sisi = float(input("Masukkan sisi persegi: "))
  return sisi * sisi

def l_persegi_panjang():
  panjang = float(input("Masukkan panjang persegi panjang: "))
  lebar = float(input("Masukkan lebar persegi panjang: "))
  return panjang * lebar

# %%
import math

numbers = float(input("Masukkan Angka = "))
akarkuadrat = math.sqrt(numbers)
print(f"Akar Kuadrat dari {numbers} = {akarkuadrat}")

decimal = float(input("Masukkan Angka desimal = "))
pembulatanatas = math.ceil(decimal)
print(f"Pembulatan Desimal {decimal} = {pembulatanatas}")

numbersfactorial = int(input("Masukkan Angka faktorial = "))
factorial = math.factorial(numbersfactorial)
print(f"Factorial dari {numbersfactorial} = {factorial}")

numberslog = float(input("Masukkan Angka Log = "))
logaritma = math.log10(numberslog)
print(f"Logaritma 10 adalah {numberslog} = {logaritma}")

derajat = float(input("Masukkan sudut derajat = "))
radian = math.radians(derajat)
print(f"Konversi {derajat} ke dalam radians {radian}")
# Out:
# Masukkan Angka = 0
# Akar Kuadrat dari 0.0 = 0.0
# Masukkan Angka desimal = 2
# Pembulatan Desimal 2.0 = 2
# Masukkan Angka faktorial = 4
# Factorial dari 4 = 24
# Masukkan Angka Log = 8
# Logaritma 10 adalah 8.0 = 0.9030899869919435
# Masukkan sudut derajat = 15
# Konversi 15.0 ke dalam radians 0.2617993877991494
