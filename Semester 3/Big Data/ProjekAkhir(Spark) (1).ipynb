# %%
# !pip install findspark
# Out:
# Requirement already satisfied: findspark in ./anaconda3/envs/ahmadya/lib/python3.13/site-packages (2.0.1)

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Data Kecelakaan').getOrCreate()

df = spark.read.csv("UK_Accident.csv", header=True, inferSchema=True)
df.show(n=5, vertical=True,  truncate=False)


df.printSchema()
print("Jumlah baris:", df.count())
print("Jumlah kolom:", len(df.columns))
# Out:
# 25/11/26 18:27:24 WARN Utils: Your hostname, ahmadyaa-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 25/11/26 18:27:24 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/26 18:27:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/26 18:27:27 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/11/26 18:27:27 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/11/26 18:27:40 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 25/11/26 18:27:44 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 25/11/26 18:27:45 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Date, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, LSOA_of_Accident_Location, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Date, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, LSOA_of_Accident_Location, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# -RECORD 0----------------------------------------------------------------------------------
#  _c0                                         | 0
#  Accident_Index                              | 200501BS00001
#  Location_Easting_OSGR                       | 525680.0
#  Location_Northing_OSGR                      | 178240.0
#  Longitude                                   | -0.19117
#  Latitude                                    | 51.489096
#  Police_Force                                | 1
#  Accident_Severity                           | 2
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 04/01/2005
#  Day_of_Week                                 | 3
#  Time                                        | 2025-11-26 17:42:00
#  Local_Authority_(District)                  | 12
#  Local_Authority_(Highway)                   | E09000020
#  1st_Road_Class                              | 3
#  1st_Road_Number                             | 3218
#  Road_Type                                   | Single carriageway
#  Speed_limit                                 | 30
#  Junction_Control                            | None
#  2nd_Road_Class                              | -1
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | None within 50 metres
#  Pedestrian_Crossing-Physical_Facilities     | Zebra crossing
#  Light_Conditions                            | Daylight: Street light present
#  Weather_Conditions                          | Raining without high winds
#  Road_Surface_Conditions                     | Wet/Damp
#  Special_Conditions_at_Site                  | None
#  Carriageway_Hazards                         | None
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | Yes
#  LSOA_of_Accident_Location                   | E01002849
#  Year                                        | 2005
# -RECORD 1----------------------------------------------------------------------------------
#  _c0                                         | 1
#  Accident_Index                              | 200501BS00002
#  Location_Easting_OSGR                       | 524170.0
#  Location_Northing_OSGR                      | 181650.0
#  Longitude                                   | -0.211708
#  Latitude                                    | 51.520075
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 05/01/2005
#  Day_of_Week                                 | 4
#  Time                                        | 2025-11-26 17:36:00
#  Local_Authority_(District)                  | 12
#  Local_Authority_(Highway)                   | E09000020
#  1st_Road_Class                              | 4
#  1st_Road_Number                             | 450
#  Road_Type                                   | Dual carriageway
#  Speed_limit                                 | 30
#  Junction_Control                            | Automatic traffic signal
#  2nd_Road_Class                              | 5
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | None within 50 metres
#  Pedestrian_Crossing-Physical_Facilities     | Pedestrian phase at traffic signal junction
#  Light_Conditions                            | Darkness: Street lights present and lit
#  Weather_Conditions                          | Fine without high winds
#  Road_Surface_Conditions                     | Dry
#  Special_Conditions_at_Site                  | None
#  Carriageway_Hazards                         | None
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | Yes
#  LSOA_of_Accident_Location                   | E01002909
#  Year                                        | 2005
# -RECORD 2----------------------------------------------------------------------------------
#  _c0                                         | 2
#  Accident_Index                              | 200501BS00003
#  Location_Easting_OSGR                       | 524520.0
#  Location_Northing_OSGR                      | 182240.0
#  Longitude                                   | -0.206458
#  Latitude                                    | 51.525301
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 06/01/2005
#  Day_of_Week                                 | 5
#  Time                                        | 2025-11-26 00:15:00
#  Local_Authority_(District)                  | 12
#  Local_Authority_(Highway)                   | E09000020
#  1st_Road_Class                              | 5
#  1st_Road_Number                             | 0
#  Road_Type                                   | Single carriageway
#  Speed_limit                                 | 30
#  Junction_Control                            | None
#  2nd_Road_Class                              | -1
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | None within 50 metres
#  Pedestrian_Crossing-Physical_Facilities     | No physical crossing within 50 meters
#  Light_Conditions                            | Darkness: Street lights present and lit
#  Weather_Conditions                          | Fine without high winds
#  Road_Surface_Conditions                     | Dry
#  Special_Conditions_at_Site                  | None
#  Carriageway_Hazards                         | None
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | Yes
#  LSOA_of_Accident_Location                   | E01002857
#  Year                                        | 2005
# -RECORD 3----------------------------------------------------------------------------------
#  _c0                                         | 3
#  Accident_Index                              | 200501BS00004
#  Location_Easting_OSGR                       | 526900.0
#  Location_Northing_OSGR                      | 177530.0
#  Longitude                                   | -0.173862
#  Latitude                                    | 51.482442
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 07/01/2005
#  Day_of_Week                                 | 6
#  Time                                        | 2025-11-26 10:35:00
#  Local_Authority_(District)                  | 12
#  Local_Authority_(Highway)                   | E09000020
#  1st_Road_Class                              | 3
#  1st_Road_Number                             | 3220
#  Road_Type                                   | Single carriageway
#  Speed_limit                                 | 30
#  Junction_Control                            | None
#  2nd_Road_Class                              | -1
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | None within 50 metres
#  Pedestrian_Crossing-Physical_Facilities     | No physical crossing within 50 meters
#  Light_Conditions                            | Daylight: Street light present
#  Weather_Conditions                          | Fine without high winds
#  Road_Surface_Conditions                     | Dry
#  Special_Conditions_at_Site                  | None
#  Carriageway_Hazards                         | None
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | Yes
#  LSOA_of_Accident_Location                   | E01002840
#  Year                                        | 2005
# -RECORD 4----------------------------------------------------------------------------------
#  _c0                                         | 4
#  Accident_Index                              | 200501BS00005
#  Location_Easting_OSGR                       | 528060.0
#  Location_Northing_OSGR                      | 179040.0
#  Longitude                                   | -0.156618
#  Latitude                                    | 51.495752
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 10/01/2005
#  Day_of_Week                                 | 2
#  Time                                        | 2025-11-26 21:13:00
#  Local_Authority_(District)                  | 12
#  Local_Authority_(Highway)                   | E09000020
#  1st_Road_Class                              | 6
#  1st_Road_Number                             | 0
#  Road_Type                                   | Single carriageway
#  Speed_limit                                 | 30
#  Junction_Control                            | None
#  2nd_Road_Class                              | -1
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | None within 50 metres
#  Pedestrian_Crossing-Physical_Facilities     | No physical crossing within 50 meters
#  Light_Conditions                            | Darkness: Street lighting unknown
#  Weather_Conditions                          | Fine without high winds
#  Road_Surface_Conditions                     | Wet/Damp
#  Special_Conditions_at_Site                  | None
#  Carriageway_Hazards                         | None
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | Yes
#  LSOA_of_Accident_Location                   | E01002863
#  Year                                        | 2005
# only showing top 5 rows
#
# root
#  |-- _c0: integer (nullable = true)
#  |-- Accident_Index: string (nullable = true)
#  |-- Location_Easting_OSGR: double (nullable = true)
#  |-- Location_Northing_OSGR: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Police_Force: integer (nullable = true)
#  |-- Accident_Severity: integer (nullable = true)
#  |-- Number_of_Vehicles: integer (nullable = true)
#  |-- Number_of_Casualties: integer (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Day_of_Week: integer (nullable = true)
#  |-- Time: timestamp (nullable = true)
#  |-- Local_Authority_(District): integer (nullable = true)
#  |-- Local_Authority_(Highway): string (nullable = true)
#  |-- 1st_Road_Class: integer (nullable = true)
#  |-- 1st_Road_Number: integer (nullable = true)
#  |-- Road_Type: string (nullable = true)
#  |-- Speed_limit: integer (nullable = true)
#  |-- Junction_Control: string (nullable = true)
#  |-- 2nd_Road_Class: integer (nullable = true)
#  |-- 2nd_Road_Number: integer (nullable = true)
#  |-- Pedestrian_Crossing-Human_Control: string (nullable = true)
#  |-- Pedestrian_Crossing-Physical_Facilities: string (nullable = true)
#  |-- Light_Conditions: string (nullable = true)
#  |-- Weather_Conditions: string (nullable = true)
#  |-- Road_Surface_Conditions: string (nullable = true)
#  |-- Special_Conditions_at_Site: string (nullable = true)
#  |-- Carriageway_Hazards: string (nullable = true)
#  |-- Urban_or_Rural_Area: integer (nullable = true)
#  |-- Did_Police_Officer_Attend_Scene_of_Accident: string (nullable = true)
#  |-- LSOA_of_Accident_Location: string (nullable = true)
#  |-- Year: integer (nullable = true)
# [Stage 3:============================================>              (6 + 2) / 8]
# Jumlah baris: 1504150
# Jumlah kolom: 33

# %%
from pyspark.sql.functions import col, count, desc

# Mencari mode kolom Pedestrian_Crossing-Human_Control
mode_pc_hc = (df.groupBy("Pedestrian_Crossing-Human_Control")
                .count()
                .orderBy(desc("count"))
                .first()[0])

df = df.fillna({"Pedestrian_Crossing-Human_Control": mode_pc_hc})

# %%
mode_pc_pf = (df.groupBy("Pedestrian_Crossing-Physical_Facilities")
                .count()
                .orderBy(desc("count"))
                .first()[0])

df = df.fillna({"Pedestrian_Crossing-Physical_Facilities": mode_pc_pf})

# %%
df = df.dropna(subset=["Time", "Longitude", "Location_Easting_OSGR"])

# %%
df = df.drop("LSOA_of_Accident_Location")

# %%
from pyspark.sql.functions import to_timestamp, concat_ws

df = df.withColumn("DateTime", to_timestamp(concat_ws(" ", "Date", "Time"), "dd/MM/yyyy HH:mm:ss"))
df = df.drop("Date", "Time")

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol="Weather_Conditions", outputCol="Weather_Indexed")
df = indexer.fit(df).transform(df)

# %%
from pyspark.sql.functions import col, sum

missing = df.select([sum(col(c).isNull().cast("int")).alias(c) for c in df.columns])
missing.show(vertical=True, truncate=False)
# Out:
# 25/11/26 18:28:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Date, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Date, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# [Stage 15:==================================================>       (7 + 1) / 8]
# -RECORD 0----------------------------------------------
#  _c0                                         | 0
#  Accident_Index                              | 0
#  Location_Easting_OSGR                       | 0
#  Location_Northing_OSGR                      | 0
#  Longitude                                   | 0
#  Latitude                                    | 0
#  Police_Force                                | 0
#  Accident_Severity                           | 0
#  Number_of_Vehicles                          | 0
#  Number_of_Casualties                        | 0
#  Day_of_Week                                 | 0
#  Local_Authority_(District)                  | 0
#  Local_Authority_(Highway)                   | 0
#  1st_Road_Class                              | 0
#  1st_Road_Number                             | 0
#  Road_Type                                   | 0
#  Speed_limit                                 | 0
#  Junction_Control                            | 0
#  2nd_Road_Class                              | 0
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | 0
#  Pedestrian_Crossing-Physical_Facilities     | 0
#  Light_Conditions                            | 0
#  Weather_Conditions                          | 0
#  Road_Surface_Conditions                     | 0
#  Special_Conditions_at_Site                  | 0
#  Carriageway_Hazards                         | 0
#  Urban_or_Rural_Area                         | 0
#  Did_Police_Officer_Attend_Scene_of_Accident | 0
#  Year                                        | 0
#  DateTime                                    | 1503932
#  Weather_Indexed                             | 0

# %%
df = df.drop("DateTime")

# %%
from pyspark.sql.functions import col, sum

missing = df.select([sum(col(c).isNull().cast("int")).alias(c) for c in df.columns])
missing.show(vertical=True, truncate=False)
# Out:
# 25/11/26 18:29:07 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# [Stage 18:==================================================>       (7 + 1) / 8]
# -RECORD 0------------------------------------------
#  _c0                                         | 0
#  Accident_Index                              | 0
#  Location_Easting_OSGR                       | 0
#  Location_Northing_OSGR                      | 0
#  Longitude                                   | 0
#  Latitude                                    | 0
#  Police_Force                                | 0
#  Accident_Severity                           | 0
#  Number_of_Vehicles                          | 0
#  Number_of_Casualties                        | 0
#  Day_of_Week                                 | 0
#  Local_Authority_(District)                  | 0
#  Local_Authority_(Highway)                   | 0
#  1st_Road_Class                              | 0
#  1st_Road_Number                             | 0
#  Road_Type                                   | 0
#  Speed_limit                                 | 0
#  Junction_Control                            | 0
#  2nd_Road_Class                              | 0
#  2nd_Road_Number                             | 0
#  Pedestrian_Crossing-Human_Control           | 0
#  Pedestrian_Crossing-Physical_Facilities     | 0
#  Light_Conditions                            | 0
#  Weather_Conditions                          | 0
#  Road_Surface_Conditions                     | 0
#  Special_Conditions_at_Site                  | 0
#  Carriageway_Hazards                         | 0
#  Urban_or_Rural_Area                         | 0
#  Did_Police_Officer_Attend_Scene_of_Accident | 0
#  Year                                        | 0
#  Weather_Indexed                             | 0

# %%
from pyspark.ml.feature import StringIndexer

index_cols = ["Local_Authority_(Highway)", "Road_Type", "Junction_Control", "Pedestrian_Crossing-Human_Control", "Pedestrian_Crossing-Physical_Facilities"]

for col_name in index_cols:
    indexer = StringIndexer(inputCol=col_name, outputCol=col_name+"_idx")
    df = indexer.fit(df).transform(df)

# %%
df.select("Local_Authority_(Highway)", "Local_Authority_(Highway)_idx", "Road_Type", "Road_Type_idx").show(10, vertical=True,truncate=False)
# Out:
# -RECORD 0-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 1-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Dual carriageway
#  Road_Type_idx                 | 1.0
# -RECORD 2-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 3-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 4-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 5-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 6-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 7-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Dual carriageway
#  Road_Type_idx                 | 1.0
# -RECORD 8-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# -RECORD 9-------------------------------------------
#  Local_Authority_(Highway)     | E09000020
#  Local_Authority_(Highway)_idx | 85.0
#  Road_Type                     | Single carriageway
#  Road_Type_idx                 | 0.0
# only showing top 10 rows

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Accident_Index: string (nullable = true)
#  |-- Location_Easting_OSGR: double (nullable = true)
#  |-- Location_Northing_OSGR: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Police_Force: integer (nullable = true)
#  |-- Accident_Severity: integer (nullable = true)
#  |-- Number_of_Vehicles: integer (nullable = true)
#  |-- Number_of_Casualties: integer (nullable = true)
#  |-- Day_of_Week: integer (nullable = true)
#  |-- Local_Authority_(District): integer (nullable = true)
#  |-- Local_Authority_(Highway): string (nullable = true)
#  |-- 1st_Road_Class: integer (nullable = true)
#  |-- 1st_Road_Number: integer (nullable = true)
#  |-- Road_Type: string (nullable = true)
#  |-- Speed_limit: integer (nullable = true)
#  |-- Junction_Control: string (nullable = true)
#  |-- 2nd_Road_Class: integer (nullable = true)
#  |-- 2nd_Road_Number: integer (nullable = true)
#  |-- Pedestrian_Crossing-Human_Control: string (nullable = false)
#  |-- Pedestrian_Crossing-Physical_Facilities: string (nullable = false)
#  |-- Light_Conditions: string (nullable = true)
#  |-- Weather_Conditions: string (nullable = true)
#  |-- Road_Surface_Conditions: string (nullable = true)
#  |-- Special_Conditions_at_Site: string (nullable = true)
#  |-- Carriageway_Hazards: string (nullable = true)
#  |-- Urban_or_Rural_Area: integer (nullable = true)
#  |-- Did_Police_Officer_Attend_Scene_of_Accident: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Weather_Indexed: double (nullable = false)
#  |-- Local_Authority_(Highway)_idx: double (nullable = false)
#  |-- Road_Type_idx: double (nullable = false)
#  |-- Junction_Control_idx: double (nullable = false)
#  |-- Pedestrian_Crossing-Human_Control_idx: double (nullable = false)
#  |-- Pedestrian_Crossing-Physical_Facilities_idx: double (nullable = false)

# %%
from pyspark.ml.feature import VectorAssembler

lokasi_cols = [
    "Longitude",
    "Latitude",
    "Local_Authority_(Highway)_idx"
]

assembler = VectorAssembler(
    inputCols=lokasi_cols,
    outputCol="Lokasi"
)

df = assembler.transform(df)

# %%
from pyspark.ml.feature import MinMaxScaler

scaler = MinMaxScaler(inputCol="Lokasi", outputCol= "Lokasi1")
scaler_model = scaler.fit(df)
df = scaler_model.transform(df)

# %%
from pyspark.ml.feature import VectorAssembler

lingkungan_cols = [
    "Road_Type_idx",
    "Speed_limit",
    "Junction_Control_idx",
    "Pedestrian_Crossing-Human_Control_idx",
    "Pedestrian_Crossing-Physical_Facilities_idx"
]

assembler = VectorAssembler(
    inputCols=lingkungan_cols,
    outputCol="Lingkungan"
)

df = assembler.transform(df)

# %%
from pyspark.ml.feature import MinMaxScaler

scaler = MinMaxScaler(inputCol="Lingkungan", outputCol= "Lingkungan1")
scaler_model = scaler.fit(df)
df = scaler_model.transform(df)

# %%
from pyspark.ml.feature import VectorAssembler

korban_cols = [
    "Number_of_Vehicles",
    "Number_of_Casualties"
]

assembler = VectorAssembler(
    inputCols=korban_cols,
    outputCol="Korban"
)
df = assembler.transform(df)

# %%
from pyspark.ml.feature import MinMaxScaler

scaler = MinMaxScaler(inputCol="Korban", outputCol= "Korban1")
scaler_model = scaler.fit(df)
df = scaler_model.transform(df)

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Accident_Index: string (nullable = true)
#  |-- Location_Easting_OSGR: double (nullable = true)
#  |-- Location_Northing_OSGR: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Police_Force: integer (nullable = true)
#  |-- Accident_Severity: integer (nullable = true)
#  |-- Number_of_Vehicles: integer (nullable = true)
#  |-- Number_of_Casualties: integer (nullable = true)
#  |-- Day_of_Week: integer (nullable = true)
#  |-- Local_Authority_(District): integer (nullable = true)
#  |-- Local_Authority_(Highway): string (nullable = true)
#  |-- 1st_Road_Class: integer (nullable = true)
#  |-- 1st_Road_Number: integer (nullable = true)
#  |-- Road_Type: string (nullable = true)
#  |-- Speed_limit: integer (nullable = true)
#  |-- Junction_Control: string (nullable = true)
#  |-- 2nd_Road_Class: integer (nullable = true)
#  |-- 2nd_Road_Number: integer (nullable = true)
#  |-- Pedestrian_Crossing-Human_Control: string (nullable = false)
#  |-- Pedestrian_Crossing-Physical_Facilities: string (nullable = false)
#  |-- Light_Conditions: string (nullable = true)
#  |-- Weather_Conditions: string (nullable = true)
#  |-- Road_Surface_Conditions: string (nullable = true)
#  |-- Special_Conditions_at_Site: string (nullable = true)
#  |-- Carriageway_Hazards: string (nullable = true)
#  |-- Urban_or_Rural_Area: integer (nullable = true)
#  |-- Did_Police_Officer_Attend_Scene_of_Accident: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Weather_Indexed: double (nullable = false)
#  |-- Local_Authority_(Highway)_idx: double (nullable = false)
#  |-- Road_Type_idx: double (nullable = false)
#  |-- Junction_Control_idx: double (nullable = false)
#  |-- Pedestrian_Crossing-Human_Control_idx: double (nullable = false)
#  |-- Pedestrian_Crossing-Physical_Facilities_idx: double (nullable = false)
#  |-- Lokasi: vector (nullable = true)
#  |-- Lokasi1: vector (nullable = true)
#  |-- Lingkungan: vector (nullable = true)
#  |-- Lingkungan1: vector (nullable = true)
#  |-- Korban: vector (nullable = true)
#  |-- Korban1: vector (nullable = true)

# %%
feature_cols = [
    "Lokasi1",
    "Lingkungan1",
    "Korban1"
]

final_assembler = VectorAssembler(
    inputCols = feature_cols,
    outputCol = "totalFeature"
)

df = final_assembler.transform(df)

# %%
train, test = df.randomSplit([0.8, 0.2], seed=123)

# %%
from pyspark.ml.classification import LogisticRegression

lr = LogisticRegression(featuresCol = "totalFeature", labelCol = "Accident_Severity")
model = lr.fit(train)
# Out:
# 25/11/26 18:59:32 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/26 19:00:41 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 25/11/26 19:00:41 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# 25/11/26 19:00:42 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv

# %%
pred = model.transform(test)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator (
    labelCol = "Accident_Severity",
    predictionCol = "prediction",
    metricName = "accuracy"
)

accuracy = evaluator.evaluate(pred)
print("Akurasi:", accuracy)
# Out:
# 25/11/26 19:10:06 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# Akurasi: 0.8521717678513684

# %%
pred.groupBy("Accident_Severity", "prediction").count().show()
# Out:
# 25/11/26 19:12:12 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/26 19:12:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 19:12:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +-----------------+----------+------+
# |Accident_Severity|prediction| count|
# +-----------------+----------+------+
# |                2|       1.0|     8|
# |                1|       3.0|  3923|
# |                3|       1.0|    10|
# |                1|       2.0|     5|
# |                2|       3.0| 40363|
# |                3|       2.0|    34|
# |                3|       3.0|255591|
# |                2|       2.0|    27|
# |                1|       1.0|     2|
# +-----------------+----------+------+

# %%
from pyspark.sql.functions import when

df2 = df.withColumn(
    "Area_Label",
    when(df.Urban_or_Rural_Area == 1, "Perkotaan")
    .when(df.Urban_or_Rural_Area == 2, "Pedesaan")
    .otherwise("Unknown")
)

accident_count = df2.groupBy("Area_Label").count().orderBy("count", ascending=False)
pdf = accident_count.toPandas()

plt.figure(figsize=(12, 8))
plt.bar(pdf["Area_Label"], pdf["count"])
plt.title("Korban berdasarkan tempat")
plt.xlabel("Lokasi")
plt.ylabel("Jumlah kecelakaan")
plt.xticks(rotation=45)
plt.show()

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql.functions import col, sum as Fsum

#eval akurasi
evaluator = MulticlassClassificationEvaluator(
    labelCol = "Accident_Severity",
    predictionCol = "prediction",
    metricName = "accuracy"
)

accurasy = evaluator.evaluate(pred)
print("Accuracy:", accuracy)

confusion_df = pred.groupBy("Accident_Severity", "prediction").count().orderBy("Accident_severity", "prediction")
confusion_df.show()
# Out:
# 25/11/26 23:44:36 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# Accuracy: 0.8521717678513684
# 25/11/26 23:46:37 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/26 23:46:47 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:59 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:46:59 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:27 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/26 23:47:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +-----------------+----------+------+
# |Accident_Severity|prediction| count|
# +-----------------+----------+------+
# |                1|       1.0|     2|
# |                1|       2.0|     5|
# |                1|       3.0|  3923|
# |                2|       1.0|     8|
# |                2|       2.0|    27|
# |                2|       3.0| 40363|
# |                3|       1.0|    10|
# |                3|       2.0|    34|
# |                3|       3.0|255591|
# +-----------------+----------+------+

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(
    labelCol = "Accident_Severity",
    predictionCol = "prediction"
)

accuracy = evaluator.evaluate(pred, {evaluator.metricName: "accuracy"})
precision = evaluator.evaluate(pred, {evaluator.metricName: "weightedPrecision"})
recall = evaluator.evaluate(pred, {evaluator.metricName: "weightedRecall"})
f1 = evaluator.evaluate(pred, {evaluator.metricName: "f1"})

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("f1 score:", f1)
# Out:
# 25/11/27 00:13:13 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/27 00:13:57 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/27 00:14:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/27 00:14:53 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# [Stage 270:=================================================>       (7 + 1) / 8]
# Accuracy: 0.8521717678513684
# Precision: 0.7827703329924791
# Recall: 0.8521717678513683
# f1 score: 0.7844072540248062

# %%
confusion_df.show()
# Out:
# 25/11/27 00:25:58 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/27 00:26:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:14 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:26:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 280:=================================================>       (7 + 1) / 8]
# +-----------------+----------+------+
# |Accident_Severity|prediction| count|
# +-----------------+----------+------+
# |                1|       1.0|     2|
# |                1|       2.0|     5|
# |                1|       3.0|  3923|
# |                2|       1.0|     8|
# |                2|       2.0|    27|
# |                2|       3.0| 40363|
# |                3|       1.0|    10|
# |                3|       2.0|    34|
# |                3|       3.0|255591|
# +-----------------+----------+------+

# %%
from pyspark.sql.functions import when

df2 = df.withColumn(
    "label_binary",
    when(df["Accident_Severity"] == 3, 1).otherwise(0)
)

# %%
from pyspark.sql.functions import col, count

confusion_df = pred.groupBy("Accident_Severity", "prediction") \
                   .agg(count("*").alias("count")) \
                   .orderBy("Accident_Severity", "prediction")
confusion_df.show()
# Out:
# 25/11/27 00:35:29 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/27 00:35:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:47 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:47 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:47 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:47 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:57 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:59 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:35:59 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:36:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:36:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:36:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 25/11/27 00:36:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 289:=================================================>       (7 + 1) / 8]
# +-----------------+----------+------+
# |Accident_Severity|prediction| count|
# +-----------------+----------+------+
# |                1|       1.0|     2|
# |                1|       2.0|     5|
# |                1|       3.0|  3923|
# |                2|       1.0|     8|
# |                2|       2.0|    27|
# |                2|       3.0| 40363|
# |                3|       1.0|    10|
# |                3|       2.0|    34|
# |                3|       3.0|255591|
# +-----------------+----------+------+

# %%
cm_table = cm.pivot_table(
    index="Accident_Severity",
    columns="prediction",
    values="count",
    fill_value=0
)

print(cm_table)
# Out:
# prediction          1.0   2.0       3.0
# Accident_Severity
# 1                   2.0   5.0    3923.0
# 2                   8.0  27.0   40363.0
# 3                  10.0  34.0  255591.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm_table = cm_table.astype(int)


plt.figure(figsize=(8,6))
sns.heatmap(cm_table, annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Prediction")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import classification_report

y_true = pred.select("Accident_Severity").toPandas()
y_pred = pred.select("prediction").toPandas()

print(classification_report(y_true, y_pred))
# Out:
# 25/11/27 00:45:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
# 25/11/27 00:46:37 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
#  Schema: _c0, Accident_Index, Location_Easting_OSGR, Location_Northing_OSGR, Longitude, Latitude, Police_Force, Accident_Severity, Number_of_Vehicles, Number_of_Casualties, Day_of_Week, Time, Local_Authority_(District), Local_Authority_(Highway), 1st_Road_Class, 1st_Road_Number, Road_Type, Speed_limit, Junction_Control, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities, Light_Conditions, Weather_Conditions, Road_Surface_Conditions, Special_Conditions_at_Site, Carriageway_Hazards, Urban_or_Rural_Area, Did_Police_Officer_Attend_Scene_of_Accident, Year
# Expected: _c0 but found:
# CSV file: file:///home/ahmadyaa/UK_Accident.csv
#               precision    recall  f1-score   support
#
#            1       0.10      0.00      0.00      3930
#            2       0.41      0.00      0.00     40398
#            3       0.85      1.00      0.92    255635
#
#     accuracy                           0.85    299963
#    macro avg       0.45      0.33      0.31    299963
# weighted avg       0.78      0.85      0.78    299963
